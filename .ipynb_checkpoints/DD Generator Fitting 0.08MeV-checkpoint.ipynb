# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
angle = np.arange(0, 185, 5)

# %%
prob = np.array([2.804, 2.802, 2.798, 2.792, 2.782, 2.770, 2.756, 2.740, 2.721, 2.701,
                 2.679, 2.655, 2.631, 2.605, 2.578, 2.551, 2.523, 2.496, 2.468, 2.441, 
                 2.414, 2.388, 2.363, 2.339, 2.316, 2.294, 2.274, 2.255, 2.239, 2.224,
                 2.21, 2.199, 2.190, 2.182, 2.177, 2.174, 2.173])

# %%
plt.plot(angle, prob)

# %%
fit_coeff = np.polyfit(angle, prob, 3)
fit_coeff
# Out:
# array([ 2.40124383e-07, -6.21303595e-05, -7.85916373e-05,  2.80606078e+00])

# %%
fit_result = fit_coeff[0] * angle**3 + fit_coeff[1] * angle**2 + fit_coeff[2] * angle + fit_coeff[3]

# %%
plt.plot(angle, fit_result)
